# %% [markdown]
# # Ngrams

# %% [markdown]
# #### 1. Imports

# %%
import pandas as pd
import ast
from nltk.util import ngrams
from nltk.probability import FreqDist

# %% [markdown]
# #### 2. Loading the Dataset

# %%
df = pd.read_csv("/Users/sophiehamann/master-thesis-code/data/processed/11_h2_lemmatized.csv")
df["tokens"] = df["tokens"].apply(ast.literal_eval)

# %% [markdown]
# #### 3. Combine all tokens

# %%
all_tokens = [token for tokens in df["tokens"] for token in tokens]
print(f"Total tokens: {len(all_tokens)}")
# Out:
# Total tokens: 79917

# %% [markdown]
# #### 4. Generate Bigrams and Trigrams

# %%
bigrams  = list(ngrams(all_tokens, 2))
trigrams = list(ngrams(all_tokens, 3))

print(f"Total bigrams:  {len(bigrams)}")
print(f"Total trigrams: {len(trigrams)}")
# Out:
# Total bigrams:  79916
# Total trigrams: 79915

# %% [markdown]
# #### 5. Counting Frequencies

# %%
bigram_freq  = FreqDist(bigrams)
trigram_freq = FreqDist(trigrams)

print("Top 20 bigrams:")
print(bigram_freq.most_common(20))
print("---")
print("Top 20 trigrams:")
print(trigram_freq.most_common(20))
# Out:
# Top 20 bigrams:
# [(('new', 'york'), 83), (('black', 'woman'), 69), (('feminist', 'art'), 41), (('issue', 'heresy'), 37), (('would', 'like'), 34), (('art', 'politics'), 30), (('year', 'ago'), 28), (('woman', 'not'), 27), (('woman', 'work'), 26), (('year', 'old'), 25), (('heresy', 'devote'), 24), (('heresy', 'feminist'), 24), (('woman', 'art'), 22), (('no', 'one'), 21), (('woman', 'movement'), 20), (('one', 'day'), 20), (('woman', 'aware'), 19), (('woman', 'music'), 19), (('first', 'time'), 19), (('work', 'together'), 19)]
# ---
# Top 20 trigrams:
# [(('heresy', 'feminist', 'art'), 23), (('heresy', 'devote', 'examination'), 18), (('woman', 'aware', 'historically'), 18), (('feminist', 'art', 'politics'), 18), (('art', 'politics', 'publish'), 16), (('devote', 'examination', 'art'), 15), (('aware', 'historically', 'connection'), 15), (('heresy', 'structure', 'collective'), 10), (('politics', 'publish', 'winter'), 10), (('new', 'york', 'city'), 10), (('queed', 'ob', 'spade'), 10), (('structure', 'collective', 'feminist'), 9), (('live', 'new', 'york'), 9), (('third', 'world', 'woman'), 9), (('woman', 'traditional', 'art'), 9), (('c.´s', 'mother', 'm.'), 9), (('publish', 'collective', 'feminist'), 9), (('heresy', 'publish', 'collective'), 8), (('examination', 'art', 'politics'), 7), (('collective', 'feminist', 'also'), 7)]

# %% [markdown]
# #### 6. Apply Minimum frequency cutoff

# %%
min_frequency = 5

filtered_bigrams  = {gram: freq for gram, freq in bigram_freq.items() if freq >= min_frequency}
filtered_trigrams = {gram: freq for gram, freq in trigram_freq.items() if freq >= min_frequency}

print(f"Bigrams  after cutoff: {len(filtered_bigrams)}")
print(f"Trigrams after cutoff: {len(filtered_trigrams)}")
# Out:
# Bigrams  after cutoff: 394
# Trigrams after cutoff: 47

# %% [markdown]
# #### 7. Saving

# %%
df_bigrams = pd.DataFrame(
    filtered_bigrams.items(),
    columns=["bigram", "frequency"]
).sort_values("frequency", ascending=False)

df_trigrams = pd.DataFrame(
    filtered_trigrams.items(),
    columns=["trigram", "frequency"]
).sort_values("frequency", ascending=False)

df_bigrams.to_csv("/Users/sophiehamann/master-thesis-code/data/processed/12_h2_bigrams.csv", index=False)
df_trigrams.to_csv("/Users/sophiehamann/master-thesis-code/data/processed/12_h2_trigrams.csv", index=False)

print("done")
print(df_bigrams.head(10))
print(df_trigrams.head(10))
# Out:
# done
#               bigram  frequency
# 26       (new, york)         83
# 43    (black, woman)         69
# 12   (feminist, art)         41
# 102  (issue, heresy)         37
# 24     (would, like)         34
# 3    (art, politics)         30
# 34       (year, ago)         28
# 54      (woman, not)         27
# 61     (woman, work)         26
# 262      (year, old)         25
#                               trigram  frequency
# 8             (heresy, feminist, art)         23
# 0       (heresy, devote, examination)         18
# 6        (woman, aware, historically)         18
# 9           (feminist, art, politics)         18
# 10           (art, politics, publish)         16
# 7   (aware, historically, connection)         15
# 1          (devote, examination, art)         15
# 3     (heresy, structure, collective)         10
# 44                 (queed, ob, spade)         10
# 11        (politics, publish, winter)         10
